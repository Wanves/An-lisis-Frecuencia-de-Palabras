# %% [markdown]
# ### Análisis Palabras Frecuentes

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
from nltk import tokenize
from wordcloud import WordCloud
import nltk
from nltk import tokenize

# %% [markdown]
# # Análisis de textos o discursos mediante la Ciencia de Datos
#
# El análisis de textos o discursos mediante la ciencia de datos es un proceso que implica la aplicación de técnicas computacionales para extraer información significativa y conocimiento útil de grandes cantidades de texto. Este enfoque combina principios de la lingüística computacional, el procesamiento del lenguaje natural (NLP por sus siglas en inglés), la minería de textos y técnicas estadísticas para entender, organizar y sacar conclusiones de datos textuales.
#
# Aquí hay una descripción detallada de las etapas típicas involucradas en el análisis de textos mediante la ciencia de datos:
#
# 1. **Preprocesamiento de datos**: Esta etapa implica limpiar y preparar los datos textuales para el análisis. Esto puede incluir la eliminación de caracteres especiales, números, palabras comunes irrelevantes (stop words), así como la normalización del texto (por ejemplo, convertir todo el texto a minúsculas).
#
# 2. **Tokenización**: El texto se divide en unidades más pequeñas, llamadas tokens. Estos tokens pueden ser palabras individuales, frases o incluso caracteres, dependiendo de los requisitos del análisis.
#
# 3. **Análisis léxico**: En esta etapa, se examinan las palabras para comprender su significado y contexto. Esto puede incluir la identificación de raíces de palabras (stemming), lematización y etiquetado gramatical.
#
# 4. **Análisis de sentimientos**: Se determina la actitud o emoción asociada con el texto. Esto puede realizarse mediante técnicas de análisis de sentimientos que asignan polaridades (positiva, negativa o neutra) a palabras, frases o documentos completos.
#
# 5. **Extracción de características**: Se identifican y extraen características relevantes del texto que se utilizarán en el análisis posterior. Esto puede incluir la frecuencia de palabras, la co-ocurrencia de términos, la longitud del texto, entre otros.
#
# 6. **Modelado y visualización**: Se aplican técnicas estadísticas y de aprendizaje automático para modelar los datos textuales y extraer información significativa. Esto puede incluir la creación de modelos de clasificación, clustering, o generación de resúmenes automáticos. Además, la visualización de datos puede ayudar a entender patrones y tendencias en el texto.
#
# 7. **Interpretación y evaluación**: Se interpretan los resultados del análisis y se evalúa su relevancia y validez. Esto implica entender cómo las conclusiones obtenidas pueden ser aplicadas para resolver problemas específicos o tomar decisiones informadas.
#
# El análisis de textos mediante la ciencia de datos se utiliza en una variedad de campos, como la minería de opiniones en redes sociales, la detección de spam en correos electrónicos, la extracción de información en documentos médicos, la clasificación de documentos legales, entre otros. Esta metodología permite a los investigadores y profesionales obtener insights valiosos a partir de grandes volúmenes de datos textuales de manera eficiente y sistemática.

# %% [markdown]
# ------------------

# %% [markdown]
# # Fragmento Discurso Davos Javier Milei

# %%
discurso = "Buenas tardes, muchas gracias: hoy estoy acá para decirles que Occidente está en peligro, está en peligro porque aquellos, que supuestamente deben defender los valores de Occidente, se encuentran cooptados por una visión del mundo que inexorablemente conduce al socialismo, en consecuencia a la pobreza.Lamentablemente en las últimas décadas, motivados por algunos deseos bienpensantes de querer ayudar al prójimo y otros por el deseo de querer pertenecer a una casta privilegiada, los principales líderes del mundo occidental han abandonado el modelo de la libertad, por distintas versiones, de lo que llamamos colectivismo.Nosotros estamos, acá, para decirles que los experimentos colectivistas nunca son la solución a los problemas, que aquejan a los ciudadanos del mundo, sino que por el contrario son su causa. Créanme, nadie mejor que nosotros los argentinos para d
igir todos los aspectos de la vida de los individuos. Todas defienden un modelo contrario al que llevó a la humanidad al progreso más espectacular de su historia.Nosotros venimos hoy aquí a invitar a los demás países de occidente a que retomemos el camino de la prosperidad. La libertad económica, el gobierno limitado y el respeto irrestricto de la propiedad privada son elementos esenciales para el crecimiento económico.Este fenómeno de empobrecimiento que produce el colectivismo no es una fantasía. Ni tampoco fatalismo. Es una realidad que los argentinos conocemos muy bien.Porque ya lo vivimos. Ya pasamos por esto. Porque como dije antes, desde que decidimos abandonar el modelo de la libertad que nos había hecho ricos, estamos atrapados en una espiral descendiente en donde cada día somos más pobres.Ya lo vivimos nosotros. Y estamos acá para alertarlos acerca de lo que puede pasar si los países de occidente que se hicieron ricos con el modelo de la libertad, continúan por este camino de servidumbre.El caso argentino es la demostración empírica de que no importa cuán rico seas, cuantos recursos naturales tengas, no importa cuán capacitada esté la población, ni cuan educada sea, ni cuantos lingotes de oro haya en las arcas del banco central.Si se adoptan medidas que entorpecen el libre funcionamiento de los mercados, la libre competencia, los sistemas de precios libres, si se entorpece el comercio, si se atenta contra la propiedad privada, el único destino posible es la pobreza.Para finalizar, quiero dejarle un mensaje a todos los empresarios aquí presentes y a los que nos están mirando desde todos los rincones del planeta.No se dejen amedrentar ni por la casta política ni por los parásitos que viven del estado. No se entreguen a una clase política que lo único que quiere es perpetuarse en el poder y mantener sus privilegios.Ustedes son benefactores sociales. Ustedes son héroes. Ustedes son los creadores del periodo de prosperidad más extraordinario que jamás hayamos vivido. Que nadie les diga que su ambición es inmoral. Si ustedes ganan dinero es porque ofrecen un mejor producto a un mejor precio, contribuyendo de esa manera al bienestar general.No cedan al avance del estado. El estado no es la solución. El estado es el problema mismo.Ustedes son los verdaderos protagonistas de esta historia, y sepan que a partir de hoy, cuentan con un aliado inclaudicable en la republica argentina.Muchas gracias y Viva la libertad carajo."

# %%
lista_discurso = discurso.split()

# %%
lista_discurso
# Out:
# ['Buenas',
#  'tardes,',
#  'muchas',
#  'gracias:',
#  'hoy',
#  'estoy',
#  'acá',
#  'para',
#  'decirles',
#  'que',
#  'Occidente',
#  'está',
#  'en',
#  'peligro,',
#  'está',
#  'en',
#  'peligro',
#  'porque',
#  'aquellos,',
#  'que',
#  'supuestamente',
#  'deben',
#  'defender',
#  'los',
#  'valores',
#  'de',
#  'Occidente,',
#  'se',
#  'encuentran',
#  'cooptados',
#  'por',
#  'una',
#  'visión',
#  'del',
#  'mundo',
#  'que',
#  'inexorablemente',
#  'conduce',
#  'al',
#  'socialismo,',
#  'en',
#  'consecuencia',
#  'a',
#  'la',
#  'pobreza.Lamentablemente',
#  'en',
#  'las',
#  'últimas',
#  'décadas,',
#  'motivados',
#  'por',
#  'algunos',
#  'deseos',
#  'bienpensantes',
#  'de',
#  'querer',
#  'ayudar',
#  'al',
#  'prójimo',
#  'y',
#  'otros',
#  'por',
#  'el',
#  'deseo',
#  'de',
#  'querer',
#  'pertenecer',
#  'a',
#  'una',
#  'casta',
#  'privilegiada,',
#  'los',
#  'principales',
#  'líderes',
#  'del',
#  'mundo',
#  'occidental',
#  'han',
# ...

# %%
def contar_apariciones(lista, palabra):
    contador = 0
    for elemento in lista:
        if elemento.lower() == palabra:
            contador += 1
    return contador
mi_lista = lista_discurso
palabra_a_contar = "socialismo"
resultado = contar_apariciones(mi_lista, palabra_a_contar)
print(f"La palabra '{palabra_a_contar}' aparece {resultado} veces en la lista.")
# Out:
# La palabra 'socialismo' aparece 4 veces en la lista.

# %%
lista_discurso = ' '.join([lista_discurso for lista_discurso in lista_discurso])

# %%
from nltk import tokenize

# %%
discurso_davos_milei = lista_discurso
token_espacio = tokenize.WhitespaceTokenizer()
frase_token_discurso_davos_milei = token_espacio.tokenize(discurso_davos_milei)

# %%
frase_token_discurso_davos_milei
# Out:
# ['Buenas',
#  'tardes,',
#  'muchas',
#  'gracias:',
#  'hoy',
#  'estoy',
#  'acá',
#  'para',
#  'decirles',
#  'que',
#  'Occidente',
#  'está',
#  'en',
#  'peligro,',
#  'está',
#  'en',
#  'peligro',
#  'porque',
#  'aquellos,',
#  'que',
#  'supuestamente',
#  'deben',
#  'defender',
#  'los',
#  'valores',
#  'de',
#  'Occidente,',
#  'se',
#  'encuentran',
#  'cooptados',
#  'por',
#  'una',
#  'visión',
#  'del',
#  'mundo',
#  'que',
#  'inexorablemente',
#  'conduce',
#  'al',
#  'socialismo,',
#  'en',
#  'consecuencia',
#  'a',
#  'la',
#  'pobreza.Lamentablemente',
#  'en',
#  'las',
#  'últimas',
#  'décadas,',
#  'motivados',
#  'por',
#  'algunos',
#  'deseos',
#  'bienpensantes',
#  'de',
#  'querer',
#  'ayudar',
#  'al',
#  'prójimo',
#  'y',
#  'otros',
#  'por',
#  'el',
#  'deseo',
#  'de',
#  'querer',
#  'pertenecer',
#  'a',
#  'una',
#  'casta',
#  'privilegiada,',
#  'los',
#  'principales',
#  'líderes',
#  'del',
#  'mundo',
#  'occidental',
#  'han',
# ...

# %%
frecuencia_discurso_davos_milei = token_espacio.tokenize(discurso)
frecuencia = nltk.FreqDist(frecuencia_discurso_davos_milei)

# %%
df_frecuencia_discurso_davos_milei = pd.DataFrame({'palabras':list(frecuencia.keys()),'frecuencia':list(frecuencia.values())})

# %% [markdown]
# ### Cuantificación de palabras ordenadas por cantidad y orden de frecuencia de aparición

# %%
df_frecuencia_discurso_davos_milei.sort_values(by='frecuencia', ascending=False)
# Out:
#                      palabras  frecuencia
# 22                         de         191
# 9                         que         138
# 38                         la         134
# 52                         el         134
# 20                        los          68
# 143                        es          67
# 37                          a          65
# 12                         en          63
# 50                          y          61
# 30                        del          49
# 24                         se          43
# 27                        por          39
# 144                        un          38
# 34                         al          30
# 66                         lo          29
# 138                        no          28
# 7                        para          26
# 297                       más          25
# 40                        las          19
# 28                        una          18
# 74                        son          15
# ...

# %%
for i in df_frecuencia_discurso_davos_milei.iterrows():
    print(i)
# Out:
# (0, palabras      Buenas
# frecuencia         1
# Name: 0, dtype: object)
# (1, palabras      tardes,
# frecuencia          1
# Name: 1, dtype: object)
# (2, palabras      muchas
# frecuencia         1
# Name: 2, dtype: object)
# (3, palabras      gracias:
# frecuencia           1
# Name: 3, dtype: object)
# (4, palabras      hoy
# frecuencia      4
# Name: 4, dtype: object)
# (5, palabras      estoy
# frecuencia        1
# Name: 5, dtype: object)
# (6, palabras      acá
# frecuencia      2
# Name: 6, dtype: object)
# (7, palabras      para
# frecuencia      26
# Name: 7, dtype: object)
# (8, palabras      decirles
# frecuencia           2
# Name: 8, dtype: object)
# (9, palabras      que
# frecuencia    138
# Name: 9, dtype: object)
# (10, palabras      Occidente
# frecuencia            1
# Name: 10, dtype: object)
# (11, palabras      está
# frecuencia       7
# Name: 11, dtype: object)
# (12, palabras      en
# frecuencia    63
# Name: 12, dtype: object)
# ...

# %%
round(df_frecuencia_discurso_davos_milei.describe(), 2)
# Out:
#        frecuencia
# count     1196.00
# mean         2.73
# std         10.10
# min          1.00
# 25%          1.00
# 50%          1.00
# 75%          2.00
# max        191.00

# %%
df_frecuencia_discurso_davos_milei.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   palabras    1196 non-null   object
#  1   frecuencia  1196 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 18.8+ KB

# %% [markdown]
# ### Frecuencia de aparición primeras 60 Palabras ordenadas por cantidad de aparición.

# %%
def grafico():
    sns.set_theme(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.barplot(data=df_frecuencia_discurso_davos_milei.nlargest(columns='frecuencia', n=60), x='palabras', y='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_title('Frecuencia aparición de primeras 60 Palabras Texto discurso Davos Javier Milei', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabel('Palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabel('Frecuencia de aparición',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    for p in ax.patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height + 1, f'{int(height)}', ha='center', va='bottom',
                 color='indigo', fontsize=12, fontweight='bold')
    plt.legend(df_frecuencia_discurso_davos_milei.nlargest(columns='frecuencia', n=30).values, loc='best', bbox_to_anchor=(1,1.1))
    plt.show()
grafico()

# %%
def grafico():
    sns.set_theme(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.histplot(data=df_frecuencia_discurso_davos_milei.nlargest(columns='frecuencia', n=60), x='palabras', y='frecuencia', hue='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_title('Histograma Frecuencia aparición de primeras 60 Palabras Texto discurso Davos Javier Milei', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.title('Frecuencia aparición de primeras 60 Palabras Texto discurso Davos Javier Milei', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabel('palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabel('frecuencia',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    for p in ax.patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height + 1, f'{int(height)}', ha='center', va='bottom',
                 color='indigo', fontsize=12, fontweight='bold')
    plt.legend(df_frecuencia_discurso_davos_milei.nlargest(columns='frecuencia', n=60))
    plt.show()
grafico()

# %%
def grafico():
    sns.set_theme(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.jointplot(data=df_frecuencia_discurso_davos_milei.nlargest(columns='frecuencia', n=60), x='palabras',y='frecuencia', palette='inferno');
    ax.figure.set_size_inches(20,7)
    plt.title('Histograma Frecuencia aparición  Palabras Texto discurso Davos Javier Milei' ,fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.title('Histograma Frecuencia aparición  Palabras Texto discurso Davos Javier Milei', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.xlabel('Palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.ylabel('Frecuencia',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(df_frecuencia_discurso_davos_milei.nlargest(columns='frecuencia', n=20).values, loc='upper right', bbox_to_anchor=(1.15,.95))
    plt.show()
grafico()

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(discurso)
    plt.title('Gráfico palabras Frecuente Fregmento Discurso Davos Javier Milei ', size= 25, color='lightblue', fontweight='bold', pad=20)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(discurso)
grafico(wordcloud)

# %% [markdown]
# ## Informe del gráfico de palabras frecuentes del discurso de Javier Milei en Davos
#
# **Palabras más frecuentes:**
#
# * **Mercado:** Es la palabra más grande y central del gráfico, lo que indica que es el tema principal del discurso de Milei.
# * **Libre:** Aparece con frecuencia y se relaciona con la visión de Milei de una sociedad libre de intervención estatal.
# * **Socialismo:** Se usa de forma negativa para criticar las políticas socialistas y colectivistas.
# * **Estado:** Se menciona en relación con su papel en la economía y la sociedad.
# * **Propiedad privada:** Se defiende como un derecho fundamental para la libertad individual.
# * **Empresa:** Se asocia con la creación de riqueza y el crecimiento económico.
# * **Economía:** Se habla de la necesidad de una economía libre y abierta.
# * **Sociedad:** Se reflexiona sobre el tipo de sociedad que se desea construir.
Muchas gracias.

 """

# %%
lista_discurso_cristina_fernadez = discurso_cristina_fernandez.split()

# %%
lista_discurso_cristina_fernadez
# Out:
# ['Muchas',
#  'gracias.',
#  '¡Viva,',
#  'viva',
#  'la',
#  'Patria,',
#  'sí!',
#  'Señores',
#  'Jefes',
#  'de',
#  'Estado',
#  'presentes;',
#  'señores',
#  'Jefes',
#  'de',
#  'Delegaciones;',
#  'señores',
#  'gobernadores;',
#  'autoridades',
#  'civiles,',
#  'militares,',
#  'eclesiásticas;',
#  'pueblo',
#  'de',
#  'la',
#  'Patria',
#  'y',
#  'Honorable',
#  'Asamblea',
#  'Legislativa:',
#  'vengo',
#  'esta',
#  'tarde',
#  'a',
#  'dar',
#  'cumplimiento',
#  'al',
#  'artículo',
#  '93',
#  'de',
#  'la',
#  'Constitución',
#  'Nacional.',
#  'Luego',
#  'de',
#  'haberse',
#  'realizado',
#  'elecciones',
#  'el',
#  '28',
#  'de',
#  'octubre,',
#  'la',
#  'fórmula',
#  'que',
#  'encabecé',
#  'junto',
#  'al',
#  'ingeniero',
#  'Julio',
#  'Cobos,',
#  'obtuvo',
#  'más',
#  'del',
#  '45',
#  'por',
#  'ciento',
#  'de',
#  'los',
#  'votos',
#  'válidos',
#  'emitidos',
#  'y,',
#  'por',
#  'lo',
#  'tanto,',
#  'no',
#  'corresponde,',
#  'tal',
# ...

# %%
'segunda' in lista_discurso_cristina_fernadez,'esos' in lista_discurso_cristina_fernadez, 'argentino' in lista_discurso_cristina_fernadez
# Out:
# (True, True, True)

# %%
lista_discurso_cristina_fernadez = ' '.join([lista_discurso_cristina_fernadez for lista_discurso_cristina_fernadez in lista_discurso_cristina_fernadez])

# %%
from nltk import tokenize

# %%
discurso_discurso_cristina_fernadez = lista_discurso_cristina_fernadez
token_espacio = tokenize.WhitespaceTokenizer()
frase_token_discurso_discurso_cristina_fernadez = token_espacio.tokenize(discurso_discurso_cristina_fernadez)

# %%
frase_token_discurso_discurso_cristina_fernadez
# Out:
# ['Muchas',
#  'gracias.',
#  '¡Viva,',
#  'viva',
#  'la',
#  'Patria,',
#  'sí!',
#  'Señores',
#  'Jefes',
#  'de',
#  'Estado',
#  'presentes;',
#  'señores',
#  'Jefes',
#  'de',
#  'Delegaciones;',
#  'señores',
#  'gobernadores;',
#  'autoridades',
#  'civiles,',
#  'militares,',
#  'eclesiásticas;',
#  'pueblo',
#  'de',
#  'la',
#  'Patria',
#  'y',
#  'Honorable',
#  'Asamblea',
#  'Legislativa:',
#  'vengo',
#  'esta',
#  'tarde',
#  'a',
#  'dar',
#  'cumplimiento',
#  'al',
#  'artículo',
#  '93',
#  'de',
#  'la',
#  'Constitución',
#  'Nacional.',
#  'Luego',
#  'de',
#  'haberse',
#  'realizado',
#  'elecciones',
#  'el',
#  '28',
#  'de',
#  'octubre,',
#  'la',
#  'fórmula',
#  'que',
#  'encabecé',
#  'junto',
#  'al',
#  'ingeniero',
#  'Julio',
#  'Cobos,',
#  'obtuvo',
#  'más',
#  'del',
#  '45',
#  'por',
#  'ciento',
#  'de',
#  'los',
#  'votos',
#  'válidos',
#  'emitidos',
#  'y,',
#  'por',
#  'lo',
#  'tanto,',
#  'no',
#  'corresponde,',
#  'tal',
# ...

# %%
frecuencia_discurso_cristina_fernadez = token_espacio.tokenize(discurso_cristina_fernandez)
frecuencia = nltk.FreqDist(frecuencia_discurso_cristina_fernadez)

# %%
df_frecuencia_discurso_cristina_fernadez = pd.DataFrame({'palabras':list(frecuencia.keys()),'frecuencia':list(frecuencia.values())})

# %%
df_frecuencia_discurso_cristina_fernadez.sort_values(by='frecuencia', ascending=False)
# Out:
#                 palabras  frecuencia
# 9                     de         251
# 44                   que         221
# 4                     la         175
# 21                     y         124
# 78                    en         117
# 28                     a         104
# 56                   los         101
# 40                    el         101
# 63                    no          66
# 132                  las          47
# 101                   un          42
# 100                   es          41
# 52                   del          39
# 61                    lo          39
# 209                   se          36
# 591              también          33
# 153                  con          33
# 97                  para          32
# 72                   una          32
# 54                   por          29
# 51                   más          26
# 118                todos          23
# 448                  nos          20
# 312               porque          19
# ...

# %%
def grafico():
    sns.set_theme(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.barplot(data=df_frecuencia_discurso_cristina_fernadez.nlargest(columns='frecuencia', n=60), x='palabras', y='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_title('Frecuencia aparición de primeras 60 Palabras Texto discurso Cristina Fernandez', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabel('Palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabel('Frecuencia de aparición',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    for p in ax.patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height + 1, f'{int(height)}', ha='center', va='bottom',
                 color='indigo', fontsize=12, fontweight='bold')
    plt.legend(df_frecuencia_discurso_cristina_fernadez.nlargest(columns='frecuencia', n=30).values, loc='best', bbox_to_anchor=(1,1.1))
    plt.show()
grafico()

# %%
def grafico():
    sns.set_theme(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.histplot(data=df_frecuencia_discurso_cristina_fernadez.nlargest(columns='frecuencia', n=60), x='palabras', y='frecuencia', hue='frecuencia',color='b',  edgecolor='k', palette='inferno');
    ax.figure.set_size_inches(20,7)
    ax.set_title('Histograma Frecuencia aparición de primeras 60 Palabras Texto discurso Davos Javier Milei', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.title('Frecuencia aparición de primeras 60 Palabras Texto discurso Cristina Fernandez', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    ax.set_xlabel('palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    ax.set_ylabel('frecuencia',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    for p in ax.patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height + 1, f'{int(height)}', ha='center', va='bottom',
                 color='indigo', fontsize=12, fontweight='bold')
    plt.legend(df_frecuencia_discurso_cristina_fernadez.nlargest(columns='frecuencia', n=60))
    plt.show()
grafico()

# %%
def grafico():
    sns.set_theme(rc={"axes.facecolor": "lightblue", "figure.facecolor": "indigo"})
    ax = sns.jointplot(data=df_frecuencia_discurso_cristina_fernadez.nlargest(columns='frecuencia', n=60), x='palabras',y='frecuencia', palette='inferno');
    ax.figure.set_size_inches(20,7)
    plt.title('Histograma Frecuencia aparición  Palabras Texto discurso Cristina Fernandez' ,fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.title('Histograma Frecuencia aparición  Palabras Texto discurso Cristina Fernandez', fontsize=25, color='lightblue', fontweight='bold', pad=20)
    plt.xlabel('Palabras', fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.ylabel('Frecuencia',fontsize=25, color='lightblue', fontweight='bold', labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold', rotation=45, ha='right')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(df_frecuencia_discurso_cristina_fernadez.nlargest(columns='frecuencia', n=20).values, loc='upper right', bbox_to_anchor=(1.15,.95))
    plt.show()
grafico()

# %%
def grafico(wordcloud):
    plt.figure(figsize=(20,7), facecolor='indigo')
    plt.imshow(wordcloud)
    wordcloud = WordCloud(width=800, height=500, collocations=False).generate(lista_discurso_cristina_fernadez)
    plt.title('Gráfico palabras Frecuente Discurso Cristina Fernadez ', size= 25, color='lightblue', fontweight='bold', pad=20)
    plt.xlabel('x', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.ylabel('y', size= 20, color='lightblue', fontweight='bold',labelpad=20)
    plt.xticks(color='lightblue', size=15, fontweight='bold')
    plt.yticks(color='lightblue', size=15, fontweight='bold')
    # plt.legend(['temperatura'], loc='best', fontsize=15)
    plt.axis('off')
    plt.show()
wordcloud = WordCloud(width=1700, height=700, collocations=False).generate(lista_discurso_cristina_fernadez)
grafico(wordcloud)

# %% [markdown]
# ## Análisis del gráfico de palabras frecuentes del discurso de Cristina Fernández
#
# El gráfico de palabras frecuentes del discurso de Cristina Fernández de Kirchner,nos permite identificar los temas principales que abordó la en su alocución.
#
# **Palabras más frecuentes:**
#
# * **Sociedad:** Hace referencia al conjunto de la población argentina y a la necesidad de construir una sociedad más justa e igualitaria.
# * **Poder:** Se refiere al poder político y a la importancia de que este esté en manos del pueblo.
# * **Desarrollo:** Se relaciona con el crecimiento económico y social del país.
# * **Libertad:** Es un valor fundamental para la democracia y la construcción de una sociedad justa.
# * **Democracia:** Es el sistema político que defiende la Presidenta y que considera como el mejor camino para el desarrollo del país.
# * **Estado:** Se refiere al conjunto de instituciones que conforman el gobierno.
# * **Justicia:** Es un valor fundamental para la sociedad y que debe ser garantizado por el Estado.
# * **Pueblo:** Es el protagonista principal de la historia y el que debe tener el poder en sus manos.
# * **Argentina:** Es el país al que se refiere la Presidenta y al que quiere construir un futuro mejor.
#
# **Otros temas importantes:**
#
# * **Igualdad:** La Presidenta se refirió a la necesidad de garantizar la igualdad de oportunidades para todos los argentinos.
# * **Educación:** Es un tema fundamental para el desarrollo del país y la Presidenta se comprometió a mejorar la calidad educativa.
# * **Economía:** La Presidenta mencionó la necesidad de reactivar la economía y generar empleo.
# * **Derechos humanos:** La Presidenta se refirió a la importancia de defender los derechos humanos y de garantizar la justicia para todos.
#
# **Conclusiones:**
#
# El gráfico de palabras frecuentes del discurso de Cristina Fernández de Kirchner nos muestra que la Presidenta abordó una amplia gama de temas en su alocución. Los temas principales fueron la sociedad, el poder, el desarrollo, la libertad, la democracia, el Estado, la justicia, el pueblo y Argentina. La Presidenta se refirió a la necesidad de construir una sociedad más justa e igualitaria, de garantizar el poder del pueblo, de desarrollar el país, de defender la libertad y la democracia, de mejorar la calidad educativa, de reactivar la economía y generar empleo, y de defender los derechos humanos.
#
# ## Impresión sentimental del gráfico
#
# **Palabras que evocan sentimientos positivos:**
#
# * **Esperanza:** El gráfico transmite un mensaje de esperanza para el futuro del país.
# * **Unidad:** Las palabras del gráfico sugieren que la Presidenta busca unir al pueblo argentino.
# * **Cambio:** El gráfico indica que la Presidenta está comprometida a realizar cambios positivos en el país.
# * **Progreso:** Las palabras del gráfico sugieren que la Presidenta busca que el país avance hacia un futuro mejor.
# * **Justicia:** El gráfico indica que la Presidenta está comprometida con la justicia social.
# * **Igualdad:** Las palabras del gráfico sugieren que la Presidenta busca construir una sociedad más justa e igualitaria.
# * **Libertad:** El gráfico indica que la Presidenta defiende la libertad y la democracia.
# * **Derechos humanos:** Las palabras del gráfico sugieren que la Presidenta está comprometida con la defensa de los derechos humanos.
# * **Patria:** El gráfico evoca un sentimiento de patriotismo y amor por el país.
# * **Orgullo:** Las palabras del gráfico sugieren que la Presidenta está orgullosa de la historia y la cultura del país.
#
# **Palabras que evocan sentimientos negativos:**
#
# * **Corrupción:** El gráfico puede despertar sentimientos de frustración e impotencia ante la corrupción en el país.
# * **Desigualdad:** Las palabras del gráfico pueden generar sentimientos de tristeza e indignación ante la desigualdad social.
# * **Pobreza:** El gráfico puede despertar sentimientos de compasión por las personas que viven en la pobreza.
# * **Violencia:** Las palabras del gráfico pueden generar sentimientos de miedo e inseguridad.
# * **Injusticia:** El gráfico puede despertar sentimientos de frustración e impotencia ante la injusticia social.
# * **Discriminación:** Las palabras del gráfico pueden generar sentimientos de tristeza e indignación ante la discriminación.
# * **Desesperanza:** El gráfico puede despertar sentimientos de desesperanza ante el futuro del país.
#
# **En general, el gráfico transmite un mensaje de esperanza y cambio positivo para el futuro del país. Sin embargo, también hay palabras que evocan sentimientos negativos como la frustración, la tristeza y la desesperanza.**
